# %%
# %load ../standard_import.txt
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns



import warnings
warnings.filterwarnings("ignore")


import datetime 
# %matplotlib inline
plt.style.use('seaborn-white')

# %%
# load dataset 


df1 = pd.read_excel(r"C:\Users\.\Downloads\Project\Database\RawData\. eQUEST v3-65 AIA_CO2 profile SImCsvReader_v4.xlsm", sheet_name="Summary", skiprows=7, skipfooter=79, index_col=0)
df1=df1.dropna(axis=1)
df1=df1.drop(columns=df1.columns[df1.eq(0).mean()>0.9])
df1=df1.T
print(df1)
# Out:
#                                     Space Cool   Heat Reject.   Refrigeration  \
# ASHRAE 90.1-2013\nBaseline Design   689.448339       0.000000       88.640348
# Proposed Design                     441.267136       5.773104       88.640348
# EEM-1 30% Resi LPD Reduction        440.468728       5.735572       88.640348
# EEM-2 MS Control                    438.676303       5.645102       88.666327
# EEM-3 Fan power Redux               434.215512       5.549538       88.666327
# EEM-4 Shower Drain HR               434.215512       5.549538       88.666327
# ALT-1 SHGC 0.34/0.25                427.945831       5.163869       88.666327
# ALT-2 SHGC 0.41/0.3                 440.181436       5.679232       88.666327
# Electric- MCD                       441.396464       5.774796       88.666327
#
#                                     Space Heat   HP Supp.   Hot Water  \
# ASHRAE 90.1-2013\nBaseline Design  3399.708312        0.0      2552.8
# ...

# %%
print(df1.columns)
# Out:
# Index([' Space Cool', ' Heat Reject.', ' Refrigeration', ' Space Heat',
#        ' HP Supp.', ' Hot Water', ' Vent. Fans', ' Pumps & Aux.',
#        ' Ext. Usage', ' Misc. Equip.', ' Task Lights', ' Area Lights',
#        ' Total', 'Regulated Total', 'HVAC Total'],
#       dtype='object')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.read_excel(r"C:\Users\.\Downloads\Project\Database\RawData\. eQUEST v3-65 AIA_CO2 profile SImCsvReader_v4.xlsm", sheet_name="Summary", skiprows=3, skipfooter=97, usecols="A:B", header=None)
print(df2)
# Out:
#                  0                1
# 0    Project Name:  xx
# 1  Square footage:           135901

# %%
df1["Project_Name"]= df2.iloc[0][1]
df1["Square_Footage"]= df2.iloc[1][1]
display(df1)
# Out:
#                                     Space Cool   Heat Reject.   Refrigeration  \
# ASHRAE 90.1-2013\nBaseline Design   689.448339       0.000000       88.640348
# Proposed Design                     441.267136       5.773104       88.640348
# EEM-1 30% Resi LPD Reduction        440.468728       5.735572       88.640348
# EEM-2 MS Control                    438.676303       5.645102       88.666327
# EEM-3 Fan power Redux               434.215512       5.549538       88.666327
# EEM-4 Shower Drain HR               434.215512       5.549538       88.666327
# ALT-1 SHGC 0.34/0.25                427.945831       5.163869       88.666327
# ALT-2 SHGC 0.41/0.3                 440.181436       5.679232       88.666327
# Electric- MCD                       441.396464       5.774796       88.666327
#
#                                     Space Heat   HP Supp.   Hot Water  \
# ASHRAE 90.1-2013\nBaseline Design  3399.708312        0.0      2552.8
# ...
